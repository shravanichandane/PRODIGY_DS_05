# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_USA=pd.read_csv(r'C:\Users\shrav\Downloads\US_Accidents_March23.csv.zip')

# %%
df_USA.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df_USA.dtypes.value_counts()
# Out:
# object     20
# bool       13
# float64    12
# int64       1
# Name: count, dtype: int64

# %%
df_USA.shape   # USA DATASET
# Out:
# (7728394, 46)

# %%
df_USA.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
df_USA.State.unique
# Out:
# <bound method Series.unique of 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 7728389    CA
# 7728390    CA
# 7728391    CA
# 7728392    CA
# 7728393    CA
# Name: State, Length: 7728394, dtype: object>

# %%
df1=df_USA[df_USA['State']=='CA']

# %%
df1
# Out:
#                 ID   Source  Severity           Start_Time  \
# 728          A-729  Source2         3  2016-06-21 10:34:40
# 729          A-730  Source2         3  2016-06-21 10:30:16
# 730          A-731  Source2         2  2016-06-21 10:49:14
# 731          A-732  Source2         3  2016-06-21 10:41:42
# 732          A-733  Source2         2  2016-06-21 10:16:26
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 728      2016-06-21 11:04:40  38.085300 -122.233017       NaN        NaN
# 729      2016-06-21 11:16:39  37.631813 -122.084167       NaN        NaN
# ...

# %%
df1.head()
# Out:
#         ID   Source  Severity           Start_Time             End_Time  \
# 728  A-729  Source2         3  2016-06-21 10:34:40  2016-06-21 11:04:40
# 729  A-730  Source2         3  2016-06-21 10:30:16  2016-06-21 11:16:39
# 730  A-731  Source2         2  2016-06-21 10:49:14  2016-06-21 11:19:14
# 731  A-732  Source2         3  2016-06-21 10:41:42  2016-06-21 11:11:42
# 732  A-733  Source2         2  2016-06-21 10:16:26  2016-06-21 11:04:16
#
#      Start_Lat   Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 728  38.085300 -122.233017      NaN      NaN           0.0  ...      False
# 729  37.631813 -122.084167      NaN      NaN           0.0  ...      False
# 730  37.896564 -122.070717      NaN      NaN           0.0  ...      False
# 731  37.334255 -122.032471      NaN      NaN           0.0  ...      False
# 732  37.250729 -121.910713      NaN      NaN           0.0  ...      False
#
#     Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df1.shape
# Out:
# (1741433, 46)

# %%
df1.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
d1f=df1.dropna(subset=['Precipitation(in)'])

# %%
df1.shape
# Out:
# (1741433, 46)

# %%
df1=df1.dropna(subset=['Temperature(F)','Wind_Chill(F)','Humidity(%)','Pressure(in)','Visibility(mi)','Wind_Direction', 'Wind_Speed(mph)',
                      'Weather_Condition'])

# %%
df1.shape
# Out:
# (1223324, 46)

# %%
df1.isna().sum()/len(df1)*100
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  22.135591
# End_Lng                  22.135591
# Distance(mi)              0.000000
# Description               0.000163
# Street                    0.192835
# City                      0.000572
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.000000
# Wind_Chill(F)             0.000000
# Humidity(%)               0.000000
# Pressure(in)              0.000000
# Visibility(mi)            0.000000
# Wind_Direction            0.000000
# Wind_Speed(mph)           0.000000
# ...

# %%
df1=df1.dropna(subset=['City','Sunrise_Sunset',
       'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'])

# %%
df1.isna().sum()/len(df1)*100
# Out:
# ID                        0.000000
# Source                    0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  22.144499
# End_Lng                  22.144499
# Distance(mi)              0.000000
# Description               0.000164
# Street                    0.192463
# City                      0.000000
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.000000
# Wind_Chill(F)             0.000000
# Humidity(%)               0.000000
# Pressure(in)              0.000000
# Visibility(mi)            0.000000
# Wind_Direction            0.000000
# Wind_Speed(mph)           0.000000
# ...

# %%
df1['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Fair                       757055
# Cloudy                     136294
# Mostly Cloudy               97801
# Partly Cloudy               78075
# Light Rain                  37422
#                             ...
# Light Snow Showers              1
# Rain Showers                    1
# Light Snow with Thunder         1
# Sand / Windy                    1
# Blowing Sand                    1
# Name: count, Length: 76, dtype: int64

# %%
df_cat=df1.select_dtypes('object')
df_num=df1.select_dtypes(np.number)
df_cat=df_cat.drop('ID',axis=1)

# %%
df_cat=df1.select_dtypes('object')
col_name=[]
length=[]

for i in df_cat.columns:
    col_name.append(i)
    length.append(len(df_cat[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#                   feature  count_of_unique_values
# 0                      ID                 1222570
# 1                  Source                       3
# 2              Start_Time                  919564
# 3                End_Time                 1074784
# 4             Description                  579784
# 5                  Street                   58486
# 6                    City                    1099
# 7                  County                      58
# 8                   State                       1
# 9                 Zipcode                  109898
# 10                Country                       1
# 11               Timezone                       2
# 12           Airport_Code                     135
# 13      Weather_Timestamp                  272950
# 14         Wind_Direction                      23
# 15      Weather_Condition                      76
# 16         Sunrise_Sunset                       2
# 17         Civil_Twilight                       2
# ...

# %%
df_num.columns
# Out:
# Index(['Severity', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng',
#        'Distance(mi)', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)',
#        'Precipitation(in)'],
#       dtype='object')

# %%
len(df_num.columns)
# Out:
# 13

# %%
df_cat.columns
# Out:
# Index(['ID', 'Source', 'Start_Time', 'End_Time', 'Description', 'Street',
#        'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Wind_Direction',
#        'Weather_Condition', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %%
#bool_col.columns
#int_col.columns
#cat_col.head()

# %%
len(df_USA['City'].unique())
# Out:
# 13679

# %%
#cat_col
#num_col_1=df.select_dtypes('number')

# %%
df_num=df1.select_dtypes(np.number)
col_name=[]
length=[]

for i in df_num.columns:
    col_name.append(i)
    length.append(len(df_num[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#               feature  count_of_unique_values
# 0            Severity                       4
# 1           Start_Lat                  396157
# 2           Start_Lng                  401200
# 3             End_Lat                  313577
# 4             End_Lng                  318210
# 5        Distance(mi)                   12929
# 6      Temperature(F)                     221
# 7       Wind_Chill(F)                     397
# 8         Humidity(%)                     100
# 9        Pressure(in)                     820
# 10     Visibility(mi)                      47
# 11    Wind_Speed(mph)                      96
# 12  Precipitation(in)                      88

# %%
plt.figure(figsize=(15 ,9))
sns.heatmap(df_num.corr() , annot=True)
# Out:
# <Axes: >

# %%
cities = df1['City'].unique()
len(cities)
# Out:
# 1099

# %%
accidents_by_cities = df1['City'].value_counts()
accidents_by_cities
# Out:
# City
# Los Angeles           104141
# Sacramento             48339
# San Diego              39373
# San Jose               21581
# Bakersfield            19109
#                        ...
# La Mesa                    1
# Desert Center              1
# Desert Hot Springs         1
# Warner Springs             1
# Canyon Lake                1
# Name: count, Length: 1099, dtype: int64

# %%
#top 10 cities by number of accident
accidents_by_cities[:10]
# Out:
# City
# Los Angeles       104141
# Sacramento         48339
# San Diego          39373
# San Jose           21581
# Bakersfield        19109
# Riverside          18845
# San Bernardino     16544
# Oakland            15236
# Fresno             14981
# Anaheim            14553
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
accidents_by_cities[:10].plot(kind='bar', color=['#264653', '#2a9d8f', '#e9c46a', '#f4a261', '#e76f51', '#b7b7b7', '#8f8f8f', '#6f6f6f', '#4f4f4f', '#2f2f2f'])

ax.set(title='Top 10 Cities by Number of Accidents')
ax.set_xlabel('Cities', fontsize=14, fontweight='bold', color='#2a9d8f')
ax.set_ylabel('Accidents Count', fontsize=14, fontweight='bold', color='#e9c46a')
plt.xticks(rotation=45, ha='right', color='black')
plt.yticks(color='black')

plt.show()

# %%
accidents_severity = df1.groupby('Severity').count()['ID']
accidents_severity
# Out:
# Severity
# 1       9790
# 2    1111818
# 3      92966
# 4       7996
# Name: ID, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))
label = [1,2,3,4]
plt.pie(accidents_severity, labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
circle = plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
ax.set_title("Accident by Severity",fontdict={'fontsize': 16})
plt.tight_layout()
plt.show()

# %%
df1['Start_Time'].dtypes
# Out:
# dtype('O')

# %%
df1['End_Time'].dtypes
# Out:
# dtype('O')

# %%
# Specify a different format
df1['Start_Time'] = pd.to_datetime(df1['Start_Time'], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')
df1['End_Time'] = pd.to_datetime(df1['End_Time'], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')

# Handle mixed formats
df1['Start_Time'] = pd.to_datetime(df1['Start_Time'], format='mixed', errors='coerce')
df1['End_Time'] = pd.to_datetime(df1['End_Time'], format='mixed', errors='coerce')

# Error handling
df1['Start_Time'] = pd.to_datetime(df1['Start_Time'], errors='coerce')
df1['End_Time'] = pd.to_datetime(df1['End_Time'], errors='coerce')

# %%
df1['Start_Time'][2408] = '2016-01-01 00:00:00'
# Out:
# C:\Users\shrav\AppData\Local\Temp\ipykernel_25036\2796422760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Start_Time'][2408] = '2016-01-01 00:00:00'

# %%
df1['End_Time'][2408] = '2019-01-01 00:00:00'
# Out:
# C:\Users\shrav\AppData\Local\Temp\ipykernel_25036\2994848631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['End_Time'][2408] = '2019-01-01 00:00:00'

# %%
# Convert 'Start_Time' column to datetime format with error handling
df1['Start_Time'] = pd.to_datetime(df1['Start_Time'], errors='coerce')

# Extract date and time components
df1['start_date'] = df1['Start_Time'].dt.date
df1['start_time'] = df1['Start_Time'].dt.time

# Handle NaT values by replacing them with appropriate placeholders
df1['start_time'] = df1['start_time'].where(~df1['Start_Time'].isna(), other=pd.NaT)

# Display the DataFrame with extracted components
print(df1[['Start_Time', 'start_date', 'start_time']])
# Out:
#         Start_Time start_date start_time
# 5041           NaT        NaN        NaN
# 5063           NaT        NaN        NaN
# 5073           NaT        NaN        NaN
# 5075           NaT        NaN        NaN
# 5080           NaT        NaN        NaN
# ...            ...        ...        ...
# 7728389        NaT        NaN        NaN
# 7728390        NaT        NaN        NaN
# 7728391        NaT        NaN        NaN
# 7728392        NaT        NaN        NaN
# 7728393        NaT        NaN        NaN
#
# [1222570 rows x 3 columns]

# %%
# Convert 'End_Time' column to datetime format with error handling
df1['End_Time'] = pd.to_datetime(df1['End_Time'], errors='coerce')

# Extract date and time components
df1['end_date'] = df1['End_Time'].dt.date

# Handle NaT values by replacing them with appropriate placeholders
df1['end_time'] = df1['End_Time'].dt.time
df1['end_time'] = df1['end_time'].where(~df1['End_Time'].isna(), other=pd.NaT)

# Display the DataFrame with extracted components
print(df1[['End_Time', 'end_date', 'end_time']])
# Out:
#         End_Time end_date end_time
# 5041         NaT      NaN      NaN
# 5063         NaT      NaN      NaN
# 5073         NaT      NaN      NaN
# 5075         NaT      NaN      NaN
# 5080         NaT      NaN      NaN
# ...          ...      ...      ...
# 7728389      NaT      NaN      NaN
# 7728390      NaT      NaN      NaN
# 7728391      NaT      NaN      NaN
# 7728392      NaT      NaN      NaN
# 7728393      NaT      NaN      NaN
#
# [1222570 rows x 3 columns]

# %%
df1['end_time']
# Out:
# 5041       NaT
# 5063       NaT
# 5073       NaT
# 5075       NaT
# 5080       NaT
#           ...
# 7728389    NaT
# 7728390    NaT
# 7728391    NaT
# 7728392    NaT
# 7728393    NaT
# Name: end_time, Length: 1222570, dtype: object

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("Start Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("End_Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
del df1['Start_Time']
del df1['End_Time']

# %%
#df.head()

# %%
# %matplotlib inline
import os

# %%
#df_num.head()
# shape of original data -> 2845342 rows

# %%
df_USA.shape  # shape of data after removing null values
# Out:
# (7728394, 46)

# %%
df_num.shape
# Out:
# (1222570, 13)

# %%
# Accidents by order of severity (1 being lowest, and 4 being highest)
df1.groupby('Severity').size()
# Out:
# Severity
# 1       9790
# 2    1111818
# 3      92966
# 4       7996
# dtype: int64

# %%
# scatter plot

df_num.plot(kind='scatter', y='Start_Lat', x='Severity')
# Out:
# <Axes: xlabel='Severity', ylabel='Start_Lat'>

# %%
sns.jointplot(x=df_num.Start_Lat.values , y=df_num.Start_Lng.values,height=10)
plt.ylabel('Start lattitude', fontsize=12)
plt.xlabel('Start lattitude', fontsize=12)
plt.show()

# %%
sns.jointplot(x=df_num.End_Lat.values , y=df_num.End_Lng.values,height=10)
plt.ylabel('end lattitude', fontsize=12)
plt.xlabel('end longitude', fontsize=12)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Analyze the 'Temperature(F)' column
sns.boxenplot(df1['Temperature(F)'])

# Analyze the 'Weather_Condition' column
data = df1['Weather_Condition'].value_counts().to_dict()
wc = WordCloud(width = 900, height = 800,background_color ='white',min_font_size = 10).generate_from_frequencies(data)
plt.imshow(wc)
plt.axis('off')
plt.show()

# Analyze the 'City' column
cities_by_accident = df1.City.value_counts()
cities_by_accident[:30].plot(kind = 'barh')

# Analyze the 'Crossing' column
df1['Crossing'].value_counts().plot(kind= 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# Count the number of accidents for each weather condition
weather_counts = df1['Weather_Condition'].value_counts()

# Create a stacked bar chart
weather_counts.plot(kind='bar', stacked=True, figsize=(10,6), color=['#264653', '#2a9d8f', '#e9c46a', '#f4a261', '#e76f51'])

plt.title('Accident Weather Conditions', fontsize=20, fontweight='bold', color='#264653')
plt.xlabel('Weather Condition', fontsize=6, fontweight='bold', color='black')
plt.ylabel('Number of Accidents', fontsize=14, fontweight='bold', color='black')
plt.xticks(rotation=45, ha='right', color='black')
plt.yticks(color='black')

plt.show()
